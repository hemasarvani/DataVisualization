# %% [markdown]
# <a href="https://colab.research.google.com/github/hemasarvani/DataVisualization/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/hemasarvani/DataVisualization.git
# Out:
# Cloning into 'DataVisualization'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (6/6), 31.39 KiB | 487.00 KiB/s, done.

# %%
ls
# Out:
# DataVisualization/  sample_data/

# %%
ls DataVisualization/
# Out:
# gapminder.tsv  README.md

# %%
import pandas as pd

# %%
df = pd.read_csv("DataVisualization/gapminder.tsv", sep =
'\t')

# %%
pd.read_csv("DataVisualization/gapminder.tsv", sep =
'\t')
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head(5)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
 df1 = df['country']

# %%
df1.head(3)
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# Name: country, dtype: object

# %%
df2 = df[['country', 'lifeExp', 'gdpPercap']]

# %%
df2.head(5)
# Out:
#        country  lifeExp   gdpPercap
# 0  Afghanistan   28.801  779.445314
# 1  Afghanistan   30.332  820.853030
# 2  Afghanistan   31.997  853.100710
# 3  Afghanistan   34.020  836.197138
# 4  Afghanistan   36.088  739.981106

# %%
df_rows = df.loc[35:40]

# %%
df_rows.head(5)
# Out:
#     country continent  year  lifeExp       pop    gdpPercap
# 35  Algeria    Africa  2007   72.301  33333216  6223.367465
# 36   Angola    Africa  1952   30.015   4232095  3520.610273
# 37   Angola    Africa  1957   31.999   4561361  3827.940465
# 38   Angola    Africa  1962   34.000   4826015  4269.276742
# 39   Angola    Africa  1967   35.985   5247469  5522.776375

# %%
df_rows.head(12)
# Out:
#     country continent  year  lifeExp       pop    gdpPercap
# 35  Algeria    Africa  2007   72.301  33333216  6223.367465
# 36   Angola    Africa  1952   30.015   4232095  3520.610273
# 37   Angola    Africa  1957   31.999   4561361  3827.940465
# 38   Angola    Africa  1962   34.000   4826015  4269.276742
# 39   Angola    Africa  1967   35.985   5247469  5522.776375
# 40   Angola    Africa  1972   37.928   5894858  5473.288005

# %%
df.groupby("country")["lifeExp"].mean()
# Out:
# country
# Afghanistan           37.478833
# Albania               68.432917
# Algeria               59.030167
# Angola                37.883500
# Argentina             69.060417
#                         ...
# Vietnam               57.479500
# West Bank and Gaza    60.328667
# Yemen, Rep.           46.780417
# Zambia                45.996333
# Zimbabwe              52.663167
# Name: lifeExp, Length: 142, dtype: float64

# %%
df.groupby("country")["gdpPercap"].mean().mean()
# Out:
# 7215.327081212147

# %%
avg_life_exp = df.groupby('year')['lifeExp'].mean().reset_index()
print(avg_life_exp)
# Out:
#     year    lifeExp
# 0   1952  49.057620
# 1   1957  51.507401
# 2   1962  53.609249
# 3   1967  55.678290
# 4   1972  57.647386
# 5   1977  59.570157
# 6   1982  61.533197
# 7   1987  63.212613
# 8   1992  64.160338
# 9   1997  65.014676
# 10  2002  65.694923
# 11  2007  67.007423

# %%
df.groupby("continent")["lifeExp", "gdpPercap"].mean()
# Out:
# <ipython-input-30-9a7a23864230>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby("continent")["lifeExp", "gdpPercap"].mean()
#              lifeExp     gdpPercap
# continent
# Africa     48.865330   2193.754578
# Americas   64.658737   7136.110356
# Asia       60.064903   7902.150428
# Europe     71.903686  14469.475533
# Oceania    74.326208  18621.609223

# %%
df.nunique()
# Out:
# country       142
# continent       5
# year           12
# lifeExp      1626
# pop          1704
# gdpPercap    1704
# dtype: int64

# %%
 df.value_counts()
# Out:
# country      continent  year  lifeExp  pop       gdpPercap
# Afghanistan  Asia       1952  28.801   8425333   779.445314      1
# Norway       Europe     1972  74.340   3933004   18965.055510    1
#                         1962  73.470   3638919   13450.401510    1
#                         1957  73.440   3491938   11653.973040    1
#                         1952  72.670   3327728   10095.421720    1
#                                                                 ..
# Germany      Europe     1957  69.100   71019069  10187.826650    1
#                         1952  67.500   69145952  7144.114393     1
# Gambia       Africa     2007  59.448   1688359   752.749726      1
#                         2002  58.041   1457766   660.585600      1
# Zimbabwe     Africa     2007  43.487   12311143  469.709298      1
# Length: 1704, dtype: int64

# %%
 df['country'].value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
df = pd.read_csv("DataVisualization/gapminder.tsv", sep =
'\t')

# %%
import matplotlib.pyplot as plt

# %%
df2=df.groupby("year")["lifeExp"].mean()

# %%
df2.plot()
# Out:
# <Axes: xlabel='year'>
